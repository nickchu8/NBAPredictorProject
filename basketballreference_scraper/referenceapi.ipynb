# %%
from basketball_reference_web_scraper import client
# Out:
# c:\Users\nyc8p\anaconda3\envs\PIC16B\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.7) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
client.standings(season_end_year=2019)
# Out:
# [{'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'wins': 58,
#   'losses': 24,
#   'division': <Division.ATLANTIC: 'ATLANTIC'>,
#   'conference': <Conference.EASTERN: 'EASTERN'>},
#  {'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'wins': 51,
#   'losses': 31,
#   'division': <Division.ATLANTIC: 'ATLANTIC'>,
#   'conference': <Conference.EASTERN: 'EASTERN'>},
#  {'team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'wins': 49,
#   'losses': 33,
#   'division': <Division.ATLANTIC: 'ATLANTIC'>,
#   'conference': <Conference.EASTERN: 'EASTERN'>},
#  {'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'wins': 42,
#   'losses': 40,
#   'division': <Division.ATLANTIC: 'ATLANTIC'>,
#   'conference': <Conference.EASTERN: 'EASTERN'>},
#  {'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'wins': 17,
#   'losses': 65,
#   'division': <Division.ATLANTIC: 'ATLANTIC'>,
#   'conference': <Conference.EASTERN: 'EASTERN'>},
# ...
