# %%
import tensorflow as tf
from tensorflow.keras import utils, models, layers
import numpy as np
import pandas as pd

# %% [markdown]
# Our first step is to create our training and testing data from all the data we downloaded.

# %%
df = pd.read_csv('output_data.csv')
df
# Out:
#           date hometeam_slug awayteam_slug  winner_is_home_team  \
# 0   2010-01-02       blazers      warriors                 True
# 1   2010-01-02         bulls         magic                 True
# 2   2010-01-02       hornets       rockets                 True
# 3   2010-01-02          suns     grizzlies                False
# 4   2010-01-02         kings     mavericks                False
# 5   2010-01-02          nets     cavaliers                False
# 6   2010-01-02         bucks       thunder                 True
# 7   2010-01-02          jazz       nuggets                False
# 8   2010-01-02       celtics       raptors                 True
# 9   2010-01-02       wizards         spurs                False
# 10  2010-01-02        pacers  timberwolves                 True
# 11  2010-01-02          heat       bobcats                False
#
#     hometeam_fieldGoalsMade  hometeam_fieldGoalsAttempted  \
# 0                        36                            74
# 1                        37                            87
# 2                        38                            85
# 3                        40                            88
# 4                        37                            92
# 5                        29                            75
# 6                        42                           106
# 7                        36                            71
# 8                        36                            70
# 9                        35                            80
# 10                       48                            98
# 11                       36                            78
#
#     hometeam_threePointersMade  hometeam_threePointersAttempted  \
# 0                            5                               15
# 1                            3                                5
# 2                            3                               14
# 3                            5                               18
# 4                            6                               18
# 5                            3                               10
# 6                            4                               17
# 7                            3                               12
# 8                            6                               16
# 9                            4                               10
# 10                          10                               25
# 11                          11                               24
#
#     hometeam_freeThrowsMade  hometeam_freeThrowsAttempted  ...  \
# 0                        28                            34  ...
# 1                        24                            27  ...
# 2                        20                            24  ...
# 3                        18                            24  ...
# 4                        11                            13  ...
# 5                        25                            32  ...
# 6                        15                            19  ...
# 7                        20                            27  ...
# 8                        25                            31  ...
# 9                        12                            17  ...
# 10                       16                            17  ...
# 11                       14                            16  ...
#
#     awayteam_threePointersAttempted  awayteam_freeThrowsMade  \
# 0                                12                       18
# 1                                37                       13
# 2                                20                       17
# 3                                15                       18
# 4                                 9                       24
# 5                                14                       26
# 6                                14                       23
# 7                                15                       16
# 8                                15                       18
# 9                                12                       15
# 10                               17                       26
# 11                               17                       28
#
#     awayteam_freeThrowsAttempted  awayteam_reboundsOffensive  \
# 0                             24                          11
# 1                             20                          16
# 2                             21                           8
# 3                             25                          16
# 4                             28                           4
# 5                             33                          16
# 6                             31                          10
# 7                             23                           8
# 8                             25                           5
# 9                             20                           3
# 10                            31                          12
# 11                            31                           4
#
#     awayteam_reboundsDefensive  awayteam_assists  awayteam_steals  \
# 0                           25                14                6
# 1                           32                19                4
# 2                           31                21                3
# 3                           33                25                7
# 4                           32                21               11
# 5                           36                19                4
# 6                           39                23                4
# 7                           24                23               15
# 8                           23                22                6
# 9                           34                23                3
# 10                          32                22                4
# 11                          28                19                6
#
#     awayteam_blocks  awayteam_foulsPersonal  awayteam_points
# 0                 1                      25               89
# 1                 7                      23               93
# 2                 1                      25               95
# 3                 5                      20              128
# 4                 4                      15               99
# 5                 5                      24               94
# 6                10                      23               97
# 7                 3                      25              105
# 8                 4                      27               96
# 9                 3                      24               97
# 10                1                      20              111
# 11                3                      18              107
#
# [12 rows x 30 columns]

# %%
df = df.drop(['date','hometeam_slug','awayteam_slug'], axis = 1)

# %%
df.columns.values.tolist()
# Out:
# ['winner_is_home_team',
#  'hometeam_fieldGoalsMade',
#  'hometeam_fieldGoalsAttempted',
#  'hometeam_threePointersMade',
#  'hometeam_threePointersAttempted',
#  'hometeam_freeThrowsMade',
#  'hometeam_freeThrowsAttempted',
#  'hometeam_reboundsOffensive',
#  'hometeam_reboundsDefensive',
#  'hometeam_assists',
#  'hometeam_steals',
#  'hometeam_blocks',
#  'hometeam_foulsPersonal',
#  'hometeam_points',
#  'awayteam_fieldGoalsMade',
#  'awayteam_fieldGoalsAttempted',
#  'awayteam_threePointersMade',
#  'awayteam_threePointersAttempted',
#  'awayteam_freeThrowsMade',
#  'awayteam_freeThrowsAttempted',
#  'awayteam_reboundsOffensive',
#  'awayteam_reboundsDefensive',
#  'awayteam_assists',
#  'awayteam_steals',
#  'awayteam_blocks',
#  'awayteam_foulsPersonal',
#  'awayteam_points']

# %%
len(df.columns.values.tolist())
# Out:
# 27

# %%
df[['awayteam_points']]
# Out:
#     awayteam_points
# 0                89
# 1                93
# 2                95
# 3               128
# 4                99
# 5                94
# 6                97
# 7               105
# 8                96
# 9                97
# 10              111
# 11              107

# %%
key_values_pairs = []
for entry in df.columns.values.tolist():
    key_values_pairs.append((entry,df[[entry]]))
key_values_pairs
# Out:
# [('winner_is_home_team',
#       winner_is_home_team
#   0                  True
#   1                  True
#   2                  True
#   3                 False
#   4                 False
#   5                 False
#   6                  True
#   7                 False
#   8                  True
#   9                 False
#   10                 True
#   11                False),
#  ('hometeam_fieldGoalsMade',
#       hometeam_fieldGoalsMade
#   0                        36
#   1                        37
#   2                        38
#   3                        40
#   4                        37
#   5                        29
#   6                        42
#   7                        36
#   8                        36
#   9                        35
#   10                       48
#   11                       36),
#  ('hometeam_fieldGoalsAttempted',
#       hometeam_fieldGoalsAttempted
#   0                             74
#   1                             87
#   2                             85
#   3                             88
#   4                             92
#   5                             75
#   6                            106
#   7                             71
#   8                             70
#   9                             80
#   10                            98
#   11                            78),
#  ('hometeam_threePointersMade',
#       hometeam_threePointersMade
#   0                            5
#   1                            3
#   2                            3
#   3                            5
#   4                            6
#   5                            3
#   6                            4
#   7                            3
#   8                            6
#   9                            4
#   10                          10
#   11                          11),
#  ('hometeam_threePointersAttempted',
#       hometeam_threePointersAttempted
#   0                                15
#   1                                 5
#   2                                14
#   3                                18
#   4                                18
#   5                                10
#   6                                17
#   7                                12
#   8                                16
#   9                                10
#   10                               25
#   11                               24),
#  ('hometeam_freeThrowsMade',
#       hometeam_freeThrowsMade
#   0                        28
#   1                        24
#   2                        20
#   3                        18
#   4                        11
#   5                        25
#   6                        15
#   7                        20
#   8                        25
#   9                        12
#   10                       16
#   11                       14),
#  ('hometeam_freeThrowsAttempted',
#       hometeam_freeThrowsAttempted
#   0                             34
#   1                             27
#   2                             24
#   3                             24
#   4                             13
#   5                             32
#   6                             19
#   7                             27
#   8                             31
#   9                             17
#   10                            17
#   11                            16),
#  ('hometeam_reboundsOffensive',
#       hometeam_reboundsOffensive
#   0                           13
#   1                           16
#   2                           10
#   3                           14
#   4                           13
#   5                            8
#   6                           19
#   7                            9
#   8                            8
#   9                            6
#   10                          12
#   11                          11),
#  ('hometeam_reboundsDefensive',
#       hometeam_reboundsDefensive
#   0                           30
#   1                           38
#   2                           27
#   3                           24
#   4                           29
#   5                           30
#   6                           35
#   7                           32
#   8                           28
#   9                           30
#   10                          30
#   11                          26),
#  ('hometeam_assists',
#       hometeam_assists
#   0                 17
#   1                 21
#   2                 18
#   3                 25
#   4                 18
#   5                 15
#   6                 15
#   7                 20
#   8                 26
#   9                 17
#   10                30
#   11                23),
#  ('hometeam_steals',
#       hometeam_steals
#   0                 6
#   1                 5
#   2                 7
#   3                 5
#   4                 4
#   5                 6
#   6                 7
#   7                 9
#   8                10
#   9                 4
#   10                6
#   11                6),
#  ('hometeam_blocks',
#       hometeam_blocks
#   0                 3
#   1                 7
#   2                 1
#   3                 8
#   4                 6
#   5                 3
#   6                 6
#   7                 6
#   8                 5
#   9                 6
#   10                7
#   11                6),
#  ('hometeam_foulsPersonal',
#       hometeam_foulsPersonal
#   0                       21
#   1                       22
#   2                       21
#   3                       21
#   4                       23
#   5                       24
#   6                       27
#   7                       22
#   8                       21
#   9                       20
#   10                      28
#   11                      23),
#  ('hometeam_points',
#       hometeam_points
#   0               105
#   1               101
#   2                99
#   3               103
#   4                91
#   5                86
#   6               103
#   7                95
#   8               103
#   9                86
#   10              122
#   11               97),
#  ('awayteam_fieldGoalsMade',
#       awayteam_fieldGoalsMade
#   0                        34
#   1                        33
#   2                        35
#   3                        51
#   4                        36
#   5                        32
#   6                        36
#   7                        42
#   8                        35
#   9                        37
#   10                       40
#   11                       35),
#  ('awayteam_fieldGoalsAttempted',
#       awayteam_fieldGoalsAttempted
#   0                             79
#   1                             92
#   2                             72
#   3                             96
#   4                             74
#   5                             81
#   6                             84
#   7                             82
#   8                             71
#   9                             73
#   10                            89
#   11                            67),
#  ('awayteam_threePointersMade',
#       awayteam_threePointersMade
#   0                            3
#   1                           14
#   2                            8
#   3                            8
#   4                            3
#   5                            4
#   6                            2
#   7                            5
#   8                            8
#   9                            8
#   10                           5
#   11                           9),
#  ('awayteam_threePointersAttempted',
#       awayteam_threePointersAttempted
#   0                                12
#   1                                37
#   2                                20
#   3                                15
#   4                                 9
#   5                                14
#   6                                14
#   7                                15
#   8                                15
#   9                                12
#   10                               17
#   11                               17),
#  ('awayteam_freeThrowsMade',
#       awayteam_freeThrowsMade
#   0                        18
#   1                        13
#   2                        17
#   3                        18
#   4                        24
#   5                        26
#   6                        23
#   7                        16
#   8                        18
#   9                        15
#   10                       26
#   11                       28),
#  ('awayteam_freeThrowsAttempted',
#       awayteam_freeThrowsAttempted
#   0                             24
#   1                             20
#   2                             21
#   3                             25
#   4                             28
#   5                             33
#   6                             31
#   7                             23
#   8                             25
#   9                             20
#   10                            31
#   11                            31),
#  ('awayteam_reboundsOffensive',
#       awayteam_reboundsOffensive
#   0                           11
#   1                           16
#   2                            8
#   3                           16
#   4                            4
#   5                           16
#   6                           10
#   7                            8
#   8                            5
#   9                            3
#   10                          12
#   11                           4),
#  ('awayteam_reboundsDefensive',
#       awayteam_reboundsDefensive
#   0                           25
#   1                           32
#   2                           31
#   3                           33
#   4                           32
#   5                           36
#   6                           39
#   7                           24
#   8                           23
#   9                           34
#   10                          32
#   11                          28),
#  ('awayteam_assists',
#       awayteam_assists
#   0                 14
#   1                 19
#   2                 21
#   3                 25
#   4                 21
#   5                 19
#   6                 23
#   7                 23
#   8                 22
#   9                 23
#   10                22
#   11                19),
#  ('awayteam_steals',
#       awayteam_steals
#   0                 6
#   1                 4
#   2                 3
#   3                 7
#   4                11
#   5                 4
#   6                 4
#   7                15
#   8                 6
#   9                 3
#   10                4
#   11                6),
#  ('awayteam_blocks',
#       awayteam_blocks
#   0                 1
#   1                 7
#   2                 1
#   3                 5
#   4                 4
#   5                 5
#   6                10
#   7                 3
#   8                 4
#   9                 3
#   10                1
#   11                3),
#  ('awayteam_foulsPersonal',
#       awayteam_foulsPersonal
#   0                       25
#   1                       23
#   2                       25
#   3                       20
#   4                       15
#   5                       24
#   6                       23
#   7                       25
#   8                       27
#   9                       24
#   10                      20
#   11                      18),
#  ('awayteam_points',
#       awayteam_points
#   0                89
#   1                93
#   2                95
#   3               128
#   4                99
#   5                94
#   6                97
#   7               105
#   8                96
#   9                97
#   10              111
#   11              107)]

# %%
def make_dataset(df):

    # create Dataset
    input_dict = dict(key_values_pairs)
    del input_dict["winner_is_home_team"]
    output_dict = {"home_win" : df["winner_is_home_team"]}
    
    Dataset = tf.data.Dataset.from_tensor_slices((input_dict, output_dict))

    # batch Dataset to increase training speed
    # Dataset = Dataset.batch(100)
    return Dataset

data = make_dataset(df) # create our dataset
data = data.shuffle(buffer_size = len(data)) # add randomization by shuffling 

train_size = int(0.8*len(data)) # split Dataset
val_size   = int(0.2*len(data)) # 20% is to be used for validation 

train = data.take(train_size) # create our training set
val = data.skip(train_size).take(val_size) # create our validation set

# %% [markdown]
# Before we create our model, we test the predictive performance of a simple Logistic Regression model first.

# %%
model_logistic_regression = models.Sequential([
    # Logistic Regression
    layers.InputLayer(input_shape=(26,)),
    layers.Dense(units=2, activation='sigmoid')
])

model_logistic_regression.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 54
#
# =================================================================
# Total params: 54 (216.00 Byte)
# Trainable params: 54 (216.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now we try our own Neural Network model.

# %%
model1 = models.Sequential([
    # NN
    layers.InputLayer(input_shape=(26,)),
    layers.Dense(units=128, use_bias=True), # Linear layer
    layers.Dense(units=128, use_bias=True, activation='relu'), # Non-Linear layer
    layers.Dense(units=256, use_bias=True), # Linear layer
    layers.Dense(units=256, use_bias=True, activation='relu'), # Non-Linear layer
    layers.Dense(units=256, use_bias=True), # Linear layer
    #layers.Flatten(),
    layers.Dense(units=64, activation='relu'), # An inner product of previous parameters with weights
    layers.Dense(units=2)
    
])

model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               1792
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 256)               33024
#
#  dense_11 (Dense)            (None, 256)               65792
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  dense_14 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 199490 (779.26 KB)
# Trainable params: 199490 (779.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.compile(optimizer='adam', # optimizer type
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # loss function
              metrics=['accuracy'])

history = model1.fit(train_dataset,
                     epochs=20,
                     validation_data=validation_dataset)

# %%
model1.predict(INSERT_INPUT)
